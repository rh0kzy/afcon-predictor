# %% [markdown]
# # 01 Data Exploration
# This notebook explores the raw datasets for the AFCON predictor project.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# Add src to path
sys.path.append(os.path.abspath('../'))
from src.config import MATCHES_RAW, FIFA_RANKING_RAW, GOALS_RAW

# Load data
matches = pd.read_csv(MATCHES_RAW)
fifa = pd.read_csv(FIFA_RANKING_RAW)
goals = pd.read_csv(GOALS_RAW)

print(f"Matches: {matches.shape}")
print(f"FIFA: {fifa.shape}")
print(f"Goals: {goals.shape}")
